# %% [markdown]
# <a href="https://colab.research.google.com/github/aasrithakallepalli/Machine_Learning_Lab/blob/main/Experiment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# File name
CSV_PATH = "diabetes Dataset.csv"

# %%
# Re-defining CSV_PATH to ensure the kernel variable is updated
CSV_PATH = "diabetes Dataset.csv"

# %%
# Read CSV file
df = pd.read_csv('/content/diabetes.csv')

# %%
# 1. Display first 5 rows
print("FIRST 5 ROWS")
print(df.head())
# Out:
# FIRST 5 ROWS
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# 2. Display dataset shape
print("\nDATASET SHAPE")
print(df.shape)
# Out:
# DATASET SHAPE
# (768, 9)

# %%
# 3. Display column names
print("\nCOLUMN NAMES")
print(df.columns)
# Out:
# COLUMN NAMES
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# 4. Display data types
print("\nDATA TYPES")
print(df.dtypes)
# Out:
# DATA TYPES
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# 5. Display basic information
print("\nDATASET INFORMATION")
df.info()
# Out:
# DATASET INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# 6. Display statistical summary
print("\nSTATISTICAL SUMMARY")
print(df.describe())
# Out:
# STATISTICAL SUMMARY
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# 7. Check missing values
print("\nMISSING VALUES")
print(df.isnull().sum())
# Out:
# MISSING VALUES
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# 8. Check duplicate rows
print("\nDUPLICATE ROWS")
print(df.duplicated().sum())
# Out:
# DUPLICATE ROWS
# 0

# %%
# 9. Diabetes status distribution
print("\nDIABETES STATUS DISTRIBUTION")
print(df["Outcome"].value_counts())
# Out:
# DIABETES STATUS DISTRIBUTION
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# 10. Placement status percentage
print("\nDIABETES STATUS PERCENTAGE")
print(df["Outcome"].value_counts(normalize=True) * 100)
# Out:
# DIABETES STATUS PERCENTAGE
# Outcome
# 0    65.104167
# 1    34.895833
# Name: proportion, dtype: float64
